# %%
from pathlib import Path
import csv

path = Path('sitka_weather.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader) # Fetch its elements one by one. If you were to iterate over reader later in the code, it would start from the second line. 
for index, column_header in enumerate(header_row):
    """The enumerate() function is a built-in function in Python that allows you to loop over a list, 
    but instead of just returning the items in the list, it also returns the index of the item in the list. 
    It essentially provides a counter for each iteration in the loop."""
    print(index, column_header)
# Out:
# 0 STATION
# 1 DATE
# 2 LATITUDE
# 3 LONGITUDE
# 4 ELEVATION
# 5 NAME
# 6 PRCP
# 7 PRCP_ATTRIBUTES
# 8 SNOW
# 9 SNOW_ATTRIBUTES
# 10 SNWD
# 11 SNWD_ATTRIBUTES
# 12 TMAX
# 13 TMAX_ATTRIBUTES
# 14 TMIN
# 15 TMIN_ATTRIBUTES
# 16 ADPT
# 17 ADPT_ATTRIBUTES
# 18 ASLP
# 19 ASLP_ATTRIBUTES
# 20 ASTP
# 21 ASTP_ATTRIBUTES
# 22 AWBT
# 23 AWBT_ATTRIBUTES
# 24 AWND
# 25 AWND_ATTRIBUTES
# 26 FMTM
# 27 FMTM_ATTRIBUTES
# 28 PGTM
# 29 PGTM_ATTRIBUTES
# 30 RHAV
# 31 RHAV_ATTRIBUTES
# 32 RHMN
# 33 RHMN_ATTRIBUTES
# 34 RHMX
# 35 RHMX_ATTRIBUTES
# 36 TAVG
# 37 TAVG_ATTRIBUTES
# 38 TOBS
# 39 TOBS_ATTRIBUTES
# 40 TSUN
# 41 TSUN_ATTRIBUTES
# 42 WDF2
# 43 WDF2_ATTRIBUTES
# 44 WDF5
# 45 WDF5_ATTRIBUTES
# 46 WDFG
# 47 WDFG_ATTRIBUTES
# 48 WSF2
# 49 WSF2_ATTRIBUTES
# 50 WSF5
# 51 WSF5_ATTRIBUTES
# 52 WSFG
# 53 WSFG_ATTRIBUTES
# 54 WT01
# 55 WT01_ATTRIBUTES
# 56 WT02
# 57 WT02_ATTRIBUTES
# 58 WT03
# 59 WT03_ATTRIBUTES
# 60 WT04
# 61 WT04_ATTRIBUTES
# 62 WT05
# 63 WT05_ATTRIBUTES
# 64 WT06
# 65 WT06_ATTRIBUTES
# ...
