# %% [markdown]
# In this project, we'll use `Matplotlib` and `Plotly` two third-party library.

# %%
import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 25]

""" The variable fig represents the entire figure, which is the collection of plots that are generated. 
The variable ax represents a single plot in the figure; 
this is the variable we’ll use most of the time when defining and customizing a single plot."""
fig, ax = plt.subplots() 
ax.plot(squares)

plt.show()

# %% [markdown]
# *   `import matplotlib.pyplot as plt`: This line is importing the pyplot module from the matplotlib library and giving it an alias plt. This is a convention in the Python community to shorten the module name. pyplot is a collection of functions that help generate plots and figures like in MATLAB.
#
# *   `squares = [1, 4, 9, 16, 25]`: Here, you're creating a Python list named squares which contains the squares of the first five integers.
#
# *   `fig, ax = plt.subplots()`: This line is initializing a figure and a set of subplots. Here, since no arguments are passed to subplots(), it creates a single plot. fig is a Figure object which is the whole window or page that everything is drawn on. ax is an Axes object or a subplot, which is an individual plot within the figure. You can have multiple subplots (Axes) in a single Figure.
#
# *   `ax.plot(squares)`: This line is plotting the squares list on the Axes object ax. Since only y values (squares) are given, x values will be automatically created as a range from 0 to N-1, where N is the number of items in squares (so here, 0 to 4).
#
# *   `plt.show()`: This line is calling the show() function which displays the plot on the screen. Until this function is called, the plot is just prepared in the background but not displayed.

# %%
import matplotlib.pyplot as plt

input_values = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]

fig, ax = plt.subplots()
ax.plot(input_values, squares, linewidth=3)

# Set chart title and label axes.
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
""" 
Here's an example of other parameters you can use: ax.tick_params(axis='both', length=10, width=2, colors='r'). 
This will make the tick lines on both axes 10 points long, 2 points wide, and red in color.
"""
ax.tick_params(labelsize=14) # The size of the tick labels on both the x and y axes are set to 14 points.

plt.show()

# %%
"""To see the full list of available styles in Matplotlib."""
import matplotlib.pyplot as plt

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt

input_values = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]

plt.style.use('seaborn') # To use any of these styles, add one line of code before calling subplots():
fig, ax = plt.subplots()
ax.plot(input_values, squares, linewidth=3)

# Set chart title and label axes.
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
ax.tick_params(labelsize=14)

plt.show()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_19716\793576532.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn') # To use any of these styles, add one line of code before calling subplots():

# %%
import matplotlib.pyplot as plt

x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=100) #  use the s argument to set the size of the dots used to draw the graph

# Set chart title and label axes.
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set size of tick labels.
ax.tick_params(labelsize=14)

plt.show()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_19716\3346741077.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# The `ax.ticklabel_format(style='plain')` is a way to modify the format of the labels on the tick marks (the numerical markers along the x and y axis).
#
# Specifically, the style parameter decides the style of the numbers used for the tick labels. There are three different styles you can choose from:
#
# `'sci'` (or 'scientific'): This uses scientific notation. For instance, 1500 would be represented as 1.5e3.
# `'plain'`: This uses plain old decimal notation. For instance, 1500 would be represented as 1500.
# `'': If the style argument is ''`, the power limits are used to determine the best format.
#
# So, ax.ticklabel_format(style='plain') sets the labels on the axes to use plain decimal notation, which can be more readable in certain circumstances (like when the numbers on the axis are not too large). Without this line, Matplotlib might use scientific notation by default if the numbers on the axis are large.

# %%
import matplotlib.pyplot as plt

x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=10)

# Set chart title and label axes.
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set the range for each axis.
"""The axis() method requires four values: the minimum and maximum values for the x-axis and the y-axis. 
Here, we run the x-axis from 0 to 1,100 and the y-axis from 0 to 1,100,000."""
ax.axis([0, 1100, 9, 1_100_000])
ax.ticklabel_format(style='plain')

plt.show()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_19716\3150246705.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ### Defining Custom Colors
#
# To change the color of the points, pass the argument color to scatter() with the name of a color to use in quotation marks, as shown here:
# ```py
# ax.scatter(x_values, y_values, color='red', s=10)
# ```
# You can also define custom colors using the RGB color model. To define a color, pass the color argument a tuple with three float values (one each for red, green, and blue, in that order), using values between 0 and 1. For example, the following line creates a plot with light-green dots:
# ```py
# ax.scatter(x_values, y_values, color=(0, 0.8, 0), s=10)
# ```
# Values closer to 0 produce darker colors, and values closer to 1 produce lighter colors.

# %% [markdown]
# ### Using a Colormap
#
# A colormap is a sequence of colors in a gradient that moves from a starting to an ending color. In visualizations, colormaps are used to emphasize patterns in data. For example, you might make low values a light color and high values a darker color.

# %%
import matplotlib.pyplot as plt

x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn')
fig, ax = plt.subplots()
"""We pass the list of y-values to c, and then tell pyplot which colormap to use with the cmap argument. 
This code colors the points with lower y-values light blue and the points with higher y-values dark blue."""
ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=10)

# Set chart title and label axes.
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set the range for each axis.
ax.axis([0, 1100, 9, 1_100_000])
"""The axis() method requires four values: the minimum and maximum values for the x-axis and the y-axis. 
Here, we run the x-axis from 0 to 1,100 and the y-axis from 0 to 1,100,000."""
ax.ticklabel_format(style='plain')

plt.savefig('squares_plot.png', bbox_inches='tight') # Save the plot to a file instead of showing it in the Matplotlib viewer
plt.show()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_19716\2347182494.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# A random walk is a mathematical object, known as a stochastic or random process, that describes a path that consists of a succession of random steps on some mathematical space such as the integers.
#
# In computer science, a random walk involves an algorithm that uses random inputs to determine the next step or direction of the movement.
#
# This concept is heavily used in areas such as physics, economics, computer science, and environmental science. It's particularly popular in areas of simulations when you need to emulate random movements or actions.
#
# Random walks have practical applications in nature, physics, biology, chemistry, and economics. For example, a pollen grain floating on a drop of water moves across the surface of the water because it’s constantly pushed around by water molecules. Molecular motion in a water drop is random, so the path a pollen grain traces on the surface is a random walk.
#
# Here is a very simple example of a random walk in python:
#
# This code will do a "random walk" over the integers. Starting from 0, at each step it randomly chooses to move one step either to the left or to the right.
#
# In more complex cases, you might take steps in more than one dimension, or choose from a larger set of possible steps, but the basic idea is the same: you're making a sequence of steps, where each move is determined by chance.

# %%
import random

# the position of the walk
position = 0

# do 100 steps
for _ in range(100):
    # each step is -1 or 1
    step = random.choice([-1, 1])
    
    # add the step to the position
    position += step
    print(position)
# Out:
# -1
# -2
# -1
# -2
# -1
# -2
# -3
# -4
# -5
# -6
# -5
# -6
# -7
# -8
# -9
# -10
# -9
# -8
# -9
# -10
# -11
# -10
# -9
# -10
# -11
# -10
# -9
# -10
# -9
# -10
# -9
# -8
# -9
# -10
# -9
# -8
# -7
# -8
# -9
# -8
# -9
# -8
# -7
# -6
# -7
# -6
# -5
# -6
# -7
# -6
# -7
# -8
# -9
# -10
# -11
# -10
# -11
# -12
# -13
# -12
# -11
# -10
# -11
# -12
# -13
# -12
# -13
# -14
# -13
# -12
# -11
# -10
# -9
# -10
# -11
# -10
# -11
# -10
# -11
# -12
# -13
# -12
# -11
# -10
# -11
# -10
# -9
# -10
# -11
# -10
# -9
# -8
# -7
# -8
# -9
# -8
# -7
# -8
# -9
# -10

# %%
import matplotlib.pyplot as plt

from random_walk import RandomWalk

# Make a random walk.
rw = RandomWalk()
rw.fill_walk()

# Plot the points in the walk.
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.scatter(rw.x_values, rw.y_values, s=15)
ax.set_aspect('equal')
plt.show()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_11236\1958122999.py:10: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import matplotlib.pyplot as plt

from random_walk import RandomWalk

# Keep making new walks, as long as the program is active.
while True:
    # Make a random walk.
    rw = RandomWalk(50_000)
    rw.fill_walk()

    # Plot the points in the walk.
    plt.style.use('classic')
    fig, ax = plt.subplots(figsize=(10, 6), dpi=128)
    point_numbers = range(rw.num_points)
    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues, edgecolors='none', s=1)
    """We use range() to generate a list of numbers equal to the number of points in the walk. 
    We assign this list to point_numbers, which we’ll use to set the color of each point in the walk. 
    We pass point_numbers to the c argument, use the Blues colormap, and then pass edgecolors='none' to get rid of the black outline around each point. 
    The result is a plot that varies from light to dark blue, showing exactly how the walk moves from its starting point to its ending point."""
    ax.set_aspect('equal')

    # Emphasize the first and last points.
    ax.scatter(0, 0, c='green', edgecolors='none', s=100)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolors='none', s=100)

    # Remove the axes.
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    plt.show()

    keep_running = input("Make another walk? (y/n): ")
    if keep_running == 'n':
        break
